# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# Jupyter_Notebook

# %% [markdown]
# Hello, this is the final assignment of the Tools for Data Science course

# %% [markdown]
# Data science languages:
#
# - Python
# - R
# - SQL
# - Scala
# - Java
# - C++
# - Julia

# %% [markdown]
# Data science libraries:
#
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - Keras
# - TensorFlow
# - ggplot2

# %% [markdown]
# |        |                   |
# |--------|-------------------|
# | Python | SQL               |
# | R      | Jupyter Notebooks |
# | GitHub | Libraries         |

# %% [markdown]
# Here are examples of arithmetic expressions:
#
# $50 + 80 = 130$
#
# $(a+b)^2 = a^2 + 2ab + b^2$
#
# $f(x) = log(x) + 2 * exp(x)$

# %%
# Adding numbers
sum = 2 + 5

# Multiplying numbers
product = 2 * 5

print(f"Sum = {sum}")
print(f"Product = {product}")
# Out:
# Sum = 7
# Product = 10

# %%
# Converting minutes to hours
minutes = 120

conversion = minutes/60

print(f"Conversion = {conversion} hours")
# Out:
# Conversion = 2.0 hours

# %% [markdown]
# Objectives: Becoming a professional data scientist

# %% [markdown]
# Author: Rodrigo Mourão Caland Dias
